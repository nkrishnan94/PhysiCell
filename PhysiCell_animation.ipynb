# %%
import svgutils.compose as sc
from IPython.display import SVG 
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import cairo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-57-63224ca4c705> in <module>()
#       5 import glob
#       6 import os
# ----> 7 import cairo
#
# ModuleNotFoundError: No module named 'cairo'

# %%
files = glob.glob("PhysiCell/output/snap*.svg")
nums = [int(files[i].split('snapshot')[1].split('.')[0]) for i in range(len(files))]
ord_files = np.array(files)[np.argsort(numbers)]

# %%
#fig.savefig('cover.svg', transparent=True)
# here starts the assembling using svgutils 
sc.Figure("20cm", "20cm", 
    sc.Panel(sc.SVG(ord_files[0]).scale(0.405))

    )

# %%
drawing = svg2rlg(ord_files[0])

# %%
plt.show(drawing)

# %%
drawing?
